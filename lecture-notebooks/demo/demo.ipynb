# %%
# Run to intialize Otter Grader 
getwd()
prefix <- "../../../shared-readwrite/lib/" 
list.files(prefix) 
source(file.path(prefix, "helpers.R"))
# Out:
# [1] "/home/jovyan/ds4all-materials-f26-public/lecture-notebooks/demo"
# [1] "demo"      "helpers.R"
# Error in library(ottr, lib.loc = "/srv/rlibs"): there is no package called ‘ottr’
# Traceback:
#
# 1. withVisible(eval(ei, envir))
# 2. eval(ei, envir)
# 3. eval(ei, envir)
# 4. library(ottr, lib.loc = "/srv/rlibs")
# 5. stop(packageNotFoundError(package, lib.loc, sys.call()))

# %% [markdown]
# **Question 1.** Assign the variable `a` the value 1.

# %%
a <- NULL # YOUR CODE HERE

# %%
. = ottr::check(file.path(prefix,"demo/q1.R"))

# %% [markdown]
# **Question 2.** Assign the variable `b` the value of 2 times `a`. (Recall `*` means multiply).

# %%
b <- NULL # YOUR CODE HERE

# %%
. = ottr::check(file.path(prefix,"demo/q2.R"))
