# %%
# Initialize Otter
library(ottr)
source("lib/helpers.R")

# %% [markdown]
# **Question 1.** Assign the variable `a` the value 1.

# %%
a <- NULL # YOUR CODE HERE

# %%
. = ottr::check("tests/q1.R")

# %% [markdown]
# **Question 2.** Use the `double_it` helper to assign `b` twice the value of `a`.

# %%
b <- NULL # YOUR CODE HERE  (hint: double_it(a))

# %%
. = ottr::check("tests/q2.R")
